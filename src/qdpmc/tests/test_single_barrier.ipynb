# %% [markdown]
# # Single Barrier UpOut

# %%
from qdpmc import *

mc = MonteCarlo(100, 1000000)
bs = BlackScholes(0.03, 0.03, 0.22, 244)
b = UpOut(
    spot=5930.0, rebate=0, barrier=6130.0, ob_days=[1],
    payoff=Payoff(plain_vanilla, strike=5630.0)
)
print(b.calc_value(mc, bs))
# Out:
# 295.1541389685277
